# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\admin

# %%
os.listdir()
# Out:
# ['.ai-navigator',
#  '.anaconda',
#  '.astropy',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.nuget',
#  '.thumbnails',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  '3d abc song chill',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'DFWNov.csv',
#  'DLX 2 ROCKY METAL LOUDER CYMBALS.ssd5kit',
#  'Documents',
#  'Downloads',
#  'environment.yml',
#  'Favorites',
#  'GameMakerProjects',
#  'IntelGraphicsProfiles',
#  'jack.iom',
#  'jacks.2ssd5kit.ssd5kit',
#  'jacks.iom',
#  'KIDS SHOW',
#  'Links',
#  'Local Settings',
#  'Models and NPCs',
#  'Music',
#  'My Documents',
#  'NCH Software Suite',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{a2332f18-cdbf-11ec-8680-002248483d79}.TM.blf',
# ...

# %%
df = pd.read_csv('DFWNov.csv')
df
# Out:
#      Estimated Equity  Estimated Margin percent  Est Unpaid Bal  Clerk Number  \
# 0            289574.0                      75.0           96706             0
# 1                 NaN                       NaN               0             0
# 2                 NaN                       NaN               0             0
# 3            235426.0                      69.0          107444             0
# 4            108425.0                      48.0          115535             0
# ..                ...                       ...             ...           ...
# 293               NaN                       NaN               0             0
# 294           74963.0                      23.0          246587             0
# 295           72023.0                      24.0          222307             0
# 296          239461.0                      86.0           37699             0
# 297           60991.0                      22.0          212429             0
#
# ...

# %%
dfrev1 = df[[
    'Mortgagor First Name',
    'Mortgagor Last Name',
    'Owner Street Number',
    'Owner Street Name',
    'City Name',
    'Estimated Equity', 
    'Estimated Margin percent'
]][0:50]

dfrev1
# Out:
#    Mortgagor First Name          Mortgagor Last Name  Owner Street Number  \
# 0                DEANNA                      PERKINS                17073
# 1                  MARC                       HARPER                15848
# 2               MICHAEL                     BENJAMIN                15811
# 3           KENDRICK  D                    ROSENDOLL                14718
# 4                ANDRES                DEL RIO TREJO                14910
# 5                 MISTY                        PAYNE                11220
# 6                JUAN M                   RICO  ETAL                 4324
# 7        WILFREDO PEREZ                 MENDEZ ET AL                 3813
# 8                 MOSHE                       ALMASI                 2620
# 9      LAUREN M/ARRON J                        BOYLE                 1012
# 10                MARIA                GUARDADO ETAL                 3001
# 11              NATOSHA                       HARRIS                  825
# ...

# %%
df.isnull().sum()
# Out:
# Estimated Equity             37
# Estimated Margin percent     37
# Est Unpaid Bal                0
# Clerk Number                  0
# Year of Report                0
# Month of Report               0
# City Name                     0
# County Code                   0
# Mapsco Page                 298
# Mapsco Section              298
# Class                         0
# Loan Type                     0
# Street Number                 0
# Address                       0
# B/B/G                         8
# Property Sq Footage           0
# Pool                         20
# Zip                           0
# Legal Description 1           0
# Legal Description 2           1
# Subdivision                   0
# Mortgagor First Name         36
# Mortgagor Last Name          28
# Mortgagee                     0
# Trustee                       0
# Auction Sale Time             0
# Volume                        0
# Page                          0
# Loan Month                    0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1784
